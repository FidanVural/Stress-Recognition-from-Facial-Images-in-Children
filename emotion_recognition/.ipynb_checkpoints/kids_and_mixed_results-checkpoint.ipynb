# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv("./data/kids_results_.csv", delimiter=",")
df.head()
# Out:
#     REAL   PRED
# 0  angry  angry
# 1  angry  angry
# 2  angry  angry
# 3  angry  angry
# 4  angry  angry

# %%
real = df.iloc[:,0]
pred = df.iloc[:,1]

# %%
def confusion_matrix_func(real, pred, path):
    plt.figure(figsize=(10,6))

    cm = confusion_matrix(real, pred)
    cmd = ConfusionMatrixDisplay(cm, display_labels=['Angry','Fear','Happy', 'Neutral','Sad','Suprise'])
    cmd.plot(cmap=plt.cm.Blues)
    cmd.ax_.set(xlabel='Predicted', ylabel='True')
    plt.show()

    cmd.figure_.savefig(path)

# %%
confusion_matrix_func(real, pred, "./results/kids_conf.jpg")

# %%
accuracy = accuracy_score(real, pred)
print(accuracy)
# Out:
# 0.8687440982058546

# %%
df = pd.read_csv("./data/mixed_results.csv", delimiter=",");
df.head()
# Out:
#     REAL   PRED
# 0  angry  happy
# 1  angry  angry
# 2  angry  angry
# 3  angry    sad
# 4  angry  angry

# %%
real = df.iloc[:,0]
pred = df.iloc[:,1]

# %%
confusion_matrix_func(real, pred, "./results/mixed_conf.jpg")

# %%
accuracy = accuracy_score(real, pred)
print(accuracy)
# Out:
# 0.6208649302121112
